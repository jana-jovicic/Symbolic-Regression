# %%
import seaborn as sns
#import scipy
#import sklearn
import pandas as pd
#import numpy as np
from datetime import datetime
from matplotlib import pyplot as plt

# %%
time_str = '00:01:15.73'
#time = datetime.strptime(time_str, '%H:%M:%S.%f')
#print(time)
#(time - datetime(1970,1,1)).total_seconds()

h, m, s = time_str.split(':')
print(h, m, s)
total_secs = float(s) + float(m)*60 + float(h)*3600
print(total_secs)
# Out:
# 00 01 15.73
# 75.73

# %%
def average_time(times):
    
    total_secs = 0
    n = 0
    for time in times:
        h, m, s = time.split(':')
        secs = float(s) + float(m)*60 + float(h)*3600
        total_secs += secs
        n += 1
    
    avg_time = round(total_secs / n, 2)
    hours, rem = divmod(avg_time, 3600)
    minutes, seconds = divmod(rem, 60)
    executionTimeFormated = '{:0>2}:{:0>2}:{:05.2f}'.format(int(hours), int(minutes), seconds)
    
    return executionTimeFormated

# %%
def analyseResults(functionName):
    
    
    print('----------------------------------------------------------')
    
    basicGPresultsPath = '../results/GP/basicGP/' + functionName + '.csv'
    dfBasicGP = pd.read_csv(basicGPresultsPath)
    
    print("Basic GP result analysis:")
    print()
    print("Mean R2 score on train data:", dfBasicGP["TrainR2Score"].mean())
    print("Mean R2 score on test data:", dfBasicGP["TestR2Score"].mean())
    
    maxTestScoreRowIdxBasicGP = dfBasicGP["TestR2Score"].idxmax()
    bestResultRowBasicGP = dfBasicGP.iloc[[maxTestScoreRowIdxBasicGP]]
    #print(bestResultRowBasicGP)
    print('Max R2 score on test data is {0} for individual {1}, simplified to {2}'.format(bestResultRowBasicGP.iloc[0]['TestR2Score'], bestResultRowBasicGP.iloc[0]['BestIndividual'], bestResultRowBasicGP.iloc[0]['BestIndividualSimplified']))
    
    if 'SympyEquivalence' in dfBasicGP.columns:
        print('Symbolical equivalence with target function:', bestResultRowBasicGP.iloc[0]['SympyEquivalence'])
        numOfSymEquivalences = 0
        if dfBasicGP['SympyEquivalence'].any():
            numOfSymEquivalences = dfBasicGP['SympyEquivalence'].value_counts()[True]
        print('Number of runs in which symbolical equivalence was achived:', numOfSymEquivalences)
    
    avg_time = average_time(dfBasicGP["Time"])
    print("Average time: ", avg_time)
    
    print('----------------------------------------------------------')
    print()
    
    
    sscGPresultsPath = '../results/GP/SSC/' + functionName + '.csv'
    dfSSCGP = pd.read_csv(sscGPresultsPath)
    
    print("GP with Semantic Similarity-based Crossover result analysis:")
    print()
    print("Mean R2 score on train data:", dfSSCGP["TrainR2Score"].mean())
    print("Mean R2 score on test data:", dfSSCGP["TestR2Score"].mean())
    
    maxTestScoreRowIdxSSCGP = dfSSCGP["TestR2Score"].idxmax()
    bestResultRowSSCGP = dfSSCGP.iloc[[maxTestScoreRowIdxSSCGP]]
    #print(bestResultRowBasicGP)
    print('Max R2 score on test data is {0} for individual {1}, simplified to {2}'.format(bestResultRowSSCGP.iloc[0]['TestR2Score'], bestResultRowSSCGP.iloc[0]['BestIndividual'], bestResultRowSSCGP.iloc[0]['BestIndividualSimplified']))
    
    if 'SympyEquivalence' in dfSSCGP.columns:
        print('Symbolical equivalence with target function:', bestResultRowSSCGP.iloc[0]['SympyEquivalence'])
        numOfSymEquivalences = 0
        if dfSSCGP['SympyEquivalence'].any():
            numOfSymEquivalences = dfSSCGP['SympyEquivalence'].value_counts()[True]
        print('Number of runs in which symbolical equivalence was achived:', numOfSymEquivalences)
        
        
    avg_time = average_time(dfSSCGP["Time"])
    print("Average time: ", avg_time)
    
    print('----------------------------------------------------------')
    print()
    
    
    vnpResultsPath = '../results/VNP/' + functionName + '.csv'
    dfVNP = pd.read_csv(vnpResultsPath)
    
    print("VNP result analysis:")
    print()
    print("Mean R2 score on train data:", dfVNP["TrainR2Score"].mean())
    print("Mean R2 score on test data:", dfVNP["TestR2Score"].mean())
    
    maxTestScoreRowIdxVNP = dfVNP["TestR2Score"].idxmax()
    bestResultRowVNP = dfVNP.iloc[[maxTestScoreRowIdxVNP]]
    #print(bestResultRowBasicGP)
    print('Max R2 score on test data is {0} for individual {1}, simplified to {2}'.format(bestResultRowVNP.iloc[0]['TestR2Score'], bestResultRowVNP.iloc[0]['BestSolution'], bestResultRowVNP.iloc[0]['BestSolutionSimplified']))
    
    if 'SympyEquivalence' in dfVNP.columns:
        print('Symbolical equivalence with target function:', bestResultRowVNP.iloc[0]['SympyEquivalence'])
        numOfSymEquivalences = 0
        if dfVNP['SympyEquivalence'].any():
            numOfSymEquivalences = dfVNP['SympyEquivalence'].value_counts()[True]
        print('Number of runs in which symbolical equivalence was achived:', numOfSymEquivalences)
        
    avg_time = average_time(dfVNP["Time"])
    print("Average time: ", avg_time)
    
    print('----------------------------------------------------------')
    print()
    

    
    mergedData = []
    
    for index, row in dfBasicGP.iterrows():
        mergedData.append([row['TrainR2Score'], 'train', 'basicGP'])
        mergedData.append([row['TestR2Score'], 'test', 'basicGP'])
        
    for index, row in dfSSCGP.iterrows():
        mergedData.append([row['TrainR2Score'], 'train', 'sscGP'])
        mergedData.append([row['TestR2Score'], 'test', 'sscGP'])
        
    for index, row in dfVNP.iterrows():
        mergedData.append([row['TrainR2Score'], 'train', 'VNP'])
        mergedData.append([row['TestR2Score'], 'test', 'VNP'])
        
    #for row in mergedData:
        #print(row)
        
    dfMerged = pd.DataFrame(mergedData, columns = ['r2_score', 'datasetType', 'metaheuristicType'])
        
    #sns.set(rc={'figure.figsize':(7,5)})
    ax = sns.boxplot(x="metaheuristicType", y="r2_score", hue="datasetType", data=dfMerged, palette="Set3")
    plt.savefig('boxplots/'+ functionName +'.png')

# %%
analyseResults('f1')
# Out:
# ----------------------------------------------------------
# Basic GP result analysis:
#
# Mean R2 score on train data: 0.9141515931401908
# Mean R2 score on test data: 0.9074026921847483
# Max R2 score on test data is 0.992114015750541 for individual ((x0 / cos(x0)) + (x0 * x0)), simplified to x0*(x0 + 1/cos(x0))
# Symbolical equivalence with target function: False
# Number of runs in which symbolical equivalence was achived: 0
# Average time:  00:00:15.65
# ----------------------------------------------------------
#
# GP with Semantic Similarity-based Crossover result analysis:
#
# Mean R2 score on train data: 0.8613699379333387
# Mean R2 score on test data: 0.8272721554239376
# Max R2 score on test data is 0.984988260834925 for individual ((x0 + (x0 * x0)) / (cos(x0)**(cos(x0)))), simplified to x0*(x0 + 1)/cos(x0)**cos(x0)
# Symbolical equivalence with target function: False
# Number of runs in which symbolical equivalence was achived: 0
# Average time:  00:00:24.98
# ----------------------------------------------------------
#
# VNP result analysis:
#
# Mean R2 score on train data: 0.8785739162456815
# Mean R2 score on test data: 0.8103839429191866
# Max R2 score on test data is 1.0 for individual (((x0 + x0) + ((x0 + (x0 * x0)) * x0)) - x0), simplified to x0*(x0*(x0 + 1) + 1)
# Symbolical equivalence with target function: True
# *********
# Number of runs in which symbolical equivalence was achived: 9
# Average time:  00:00:07.90
# ----------------------------------------------------------

# %%
analyseResults('f2')
# Out:
# ----------------------------------------------------------
# Basic GP result analysis:
#
# Mean R2 score on train data: 0.8266418455423321
# Mean R2 score on test data: 0.8239778016366329
# Max R2 score on test data is 0.9944176468217892 for individual ((x0 + (x0 * x0)) / cos(sin((sin(x0) / cos(x0))))), simplified to x0*(x0 + 1)/cos(sin(tan(x0)))
# Average time:  00:00:13.89
# ----------------------------------------------------------
#
# GP with Semantic Similarity-based Crossover result analysis:
#
# Mean R2 score on train data: 0.7991429496033916
# Mean R2 score on test data: 0.7976483082966596
# Max R2 score on test data is 0.9809793601937404 for individual (((x0 / x0) + sin(x0)) * (x0 + (x0 * x0))), simplified to x0*(x0 + 1)*(sin(x0) + 1)
# Average time:  00:00:26.05
# ----------------------------------------------------------
#
# VNP result analysis:
#
# Mean R2 score on train data: 0.808781245836646
# Mean R2 score on test data: 0.8046324435457836
# Max R2 score on test data is 1.0 for individual ((((x0 + (x0 * x0)) * x0) * x0) + (x0 + (x0 * x0))), simplified to x0*(x0**2*(x0 + 1) + x0 + 1)
# Average time:  00:00:08.61
# ----------------------------------------------------------

# %%
analyseResults('f3')
# Out:
# ----------------------------------------------------------
# Basic GP result analysis:
#
# Mean R2 score on train data: 0.8506114871025913
# Mean R2 score on test data: 0.6945540158553251
# Max R2 score on test data is 0.980890739944617 for individual ((x0 / ((cos(x0) / cos(0.542))**(x0))) / ((x0 / ((x0 / 0.235) - sin(x0)))**(x0))), simplified to X0/((1.16729*cos(x0))**x0*(x0/(4.2553*x0 - sin(x0)))**x0)
# Average time:  00:00:20.80
# ----------------------------------------------------------
#
# GP with Semantic Similarity-based Crossover result analysis:
#
# Mean R2 score on train data: 0.8506298562819317
# Mean R2 score on test data: -1.4287720436082718
# Max R2 score on test data is 0.9945475416735132 for individual (sin(x0) + (x0 * (((x0 * x0) + x0) / sin(cos(x0))))), simplified to (x0**3 + x0**2 + sin(x0)*sin(cos(x0)))/sin(cos(x0))
# Average time:  00:00:23.05
# ----------------------------------------------------------
#
# VNP result analysis:
#
# Mean R2 score on train data: 0.8871052849960596
# Mean R2 score on test data: inf
# Max R2 score on test data is inf for individual log((x0 / ((cos((x0 * -0.482)) - x0) * x0))), simplified to log(1/(-x0 + cos(0.482*x0)))
# Average time:  00:00:13.30
# ----------------------------------------------------------

# %%
analyseResults('f4')
# Out:
# ----------------------------------------------------------
# Basic GP result analysis:
#
# Mean R2 score on train data: 0.7356222098841309
# Mean R2 score on test data: 0.7866275286690968
# Max R2 score on test data is 0.9846073119380968 for individual (x0 / (0.207**(x0)))
# ----------------------------------------------------------
#
# GP with Semantic Similarity-based Crossover result analysis:
#
# Mean R2 score on train data: 0.7043058927468743
# Mean R2 score on test data: 0.757023346084523
# Max R2 score on test data is 0.961289857415044 for individual ((x0 / (cos(-0.393) - (x0 + log(cos(cos(cos(x0))))))) / cos(x0))
# ----------------------------------------------------------

# %%
analyseResults('f5')
# Out:
# ----------------------------------------------------------
# Basic GP result analysis:
#
# Mean R2 score on train data: 0.5065257327645832
# Mean R2 score on test data: 0.5432751068448192
# Max R2 score on test data is 0.9339837155630732 for individual (0.07 - cos(x0))
# ----------------------------------------------------------
#
# GP with Semantic Similarity-based Crossover result analysis:
#
# Mean R2 score on train data: 0.34927055614368674
# Mean R2 score on test data: 0.36241671106732004
# Max R2 score on test data is 0.9302344766887012 for individual (-0.934 * cos(x0))
# ----------------------------------------------------------

# %%
analyseResults('f6')
# Out:
# ----------------------------------------------------------
# Basic GP result analysis:
#
# Mean R2 score on train data: 0.9201119192671856
# Mean R2 score on test data: 0.8890453844145956
# Max R2 score on test data is 0.9867949680486656 for individual (sin((x0 + x0)) / sin((cos(-0.891)**(x0))))
# ----------------------------------------------------------
#
# GP with Semantic Similarity-based Crossover result analysis:
#
# Mean R2 score on train data: 0.9170410391481464
# Mean R2 score on test data: 0.895148563714341
# Max R2 score on test data is 0.996243269095374 for individual ((x0 + x0) * ((x0 + (log((0.534**(-0.973)))**(x0))) * cos(x0)))
# ----------------------------------------------------------

# %%
analyseResults('f7')
# Out:
# ----------------------------------------------------------
# Basic GP result analysis:
#
# Mean R2 score on train data: 0.9680609666052256
# Mean R2 score on test data: 0.959693018606411
# Max R2 score on test data is 0.9982195657398514 for individual ((x0 + x0) * cos(-0.814))
# ----------------------------------------------------------
#
# GP with Semantic Similarity-based Crossover result analysis:
#
# Mean R2 score on train data: 0.9398697544191704
# Mean R2 score on test data: 0.9318598178968022
# Max R2 score on test data is 0.9961653637252113 for individual ((x0 / 0.562) - (x0 * 0.377))
# ----------------------------------------------------------

# %%
analyseResults('f8')
# Out:
# ----------------------------------------------------------
# Basic GP result analysis:
#
# Mean R2 score on train data: 0.8704213308516685
# Mean R2 score on test data: 0.7409240923136491
# Max R2 score on test data is 0.990350076571977 for individual (sin(x0) + (x1 * x1))
# ----------------------------------------------------------
#
# GP with Semantic Similarity-based Crossover result analysis:
#
# Mean R2 score on train data: 0.8383319625558826
# Mean R2 score on test data: 0.6882836432798436
# Max R2 score on test data is 0.990350076571977 for individual ((x1 * x1) + sin(x0))
# ----------------------------------------------------------

# %%
analyseResults('f9')
# Out:
# ----------------------------------------------------------
# Basic GP result analysis:
#
# Mean R2 score on train data: 0.9514453628359382
# Mean R2 score on test data: 0.9553074902752096
# Max R2 score on test data is 0.996939128054863 for individual ((x0 + sin(x0)) * cos(x1))
# ----------------------------------------------------------
#
# GP with Semantic Similarity-based Crossover result analysis:
#
# Mean R2 score on train data: 0.9235160062505372
# Mean R2 score on test data: 0.9189647155033716
# Max R2 score on test data is 0.9877565122194516 for individual (cos(x1) * (x0 + x0))
# ----------------------------------------------------------

# %%
analyseResults('f1')
# Out:
# ----------------------------------------------------------
# Basic GP result analysis:
#
# Mean R2 score on train data: 0.9141515931401909
# Mean R2 score on test data: 0.9074026921847483
# Max R2 score on test data is 0.9921140157505406 for individual ((x0 / cos(x0)) + (x0 * x0))
# ----------------------------------------------------------
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_8810/360027668.py in <module>
# ----> 1 analyseResults('f1')
#
# /tmp/ipykernel_8810/3271892399.py in analyseResults(functionName)
#      20
#      21     sscGPresultsPath = '../results/GP/SSC/' + functionName + '.csv'
# ---> 22     dfSSCGP = pd.read_csv (sscGPresultsPath)
#      23
#      24     print("GP with Semantic Similarity-based Crossover result analysis:")
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../results/GP/SSC/f1.csv'

# %%
analyseResults('f2')
# Out:
# ----------------------------------------------------------
# Basic GP result analysis:
#
# Mean R2 score on train data: 0.8469954191093279
# Mean R2 score on test data: 0.84411440716727
# Max R2 score on test data is 0.9839410310674196 for individual (x0 / (0.29**(x0)))
# ----------------------------------------------------------
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_8810/1331586723.py in <module>
# ----> 1 analyseResults('f2')
#
# /tmp/ipykernel_8810/3271892399.py in analyseResults(functionName)
#      20
#      21     sscGPresultsPath = '../results/GP/SSC/' + functionName + '.csv'
# ---> 22     dfSSCGP = pd.read_csv (sscGPresultsPath)
#      23
#      24     print("GP with Semantic Similarity-based Crossover result analysis:")
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../results/GP/SSC/f2.csv'

# %%
analyseResults('f3')
# Out:
# ----------------------------------------------------------
# Basic GP result analysis:
#
# Mean R2 score on train data: 0.8506114871025918
# Mean R2 score on test data: 0.6945540158553251
# Max R2 score on test data is 0.9808907399446168 for individual ((x0 / ((cos(x0) / cos(0.542))**(x0))) / ((x0 / ((x0 / 0.235) - sin(x0)))**(x0)))
# ----------------------------------------------------------
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_8810/3839478054.py in <module>
# ----> 1 analyseResults('f3')
#
# /tmp/ipykernel_8810/3271892399.py in analyseResults(functionName)
#      20
#      21     sscGPresultsPath = '../results/GP/SSC/' + functionName + '.csv'
# ---> 22     dfSSCGP = pd.read_csv (sscGPresultsPath)
#      23
#      24     print("GP with Semantic Similarity-based Crossover result analysis:")
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../results/GP/SSC/f3.csv'

# %%
analyseResults('f4')
# Out:
# ----------------------------------------------------------
# Basic GP result analysis:
#
# Mean R2 score on train data: 0.7463184538919461
# Mean R2 score on test data: 0.795872061535691
# Max R2 score on test data is 0.9859846814163256 for individual (x0 / (cos(log(0.302))**((x0 / cos(x0)))))
# ----------------------------------------------------------
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_8810/1469309929.py in <module>
# ----> 1 analyseResults('f4')
#
# /tmp/ipykernel_8810/3271892399.py in analyseResults(functionName)
#      20
#      21     sscGPresultsPath = '../results/GP/SSC/' + functionName + '.csv'
# ---> 22     dfSSCGP = pd.read_csv (sscGPresultsPath)
#      23
#      24     print("GP with Semantic Similarity-based Crossover result analysis:")
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../results/GP/SSC/f4.csv'

# %%
analyseResults('f5')
# Out:
# ----------------------------------------------------------
# Basic GP result analysis:
#
# Mean R2 score on train data: 0.6431833357943357
# Mean R2 score on test data: 0.6071726906099014
# Max R2 score on test data is 0.9435017663173292 for individual (log(cos(0.925)) / sin((0.482 + (x0 * x0))))
# ----------------------------------------------------------
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_8810/3825055412.py in <module>
# ----> 1 analyseResults('f5')
#
# /tmp/ipykernel_8810/3271892399.py in analyseResults(functionName)
#      20
#      21     sscGPresultsPath = '../results/GP/SSC/' + functionName + '.csv'
# ---> 22     dfSSCGP = pd.read_csv (sscGPresultsPath)
#      23
#      24     print("GP with Semantic Similarity-based Crossover result analysis:")
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../results/GP/SSC/f5.csv'

# %%
analyseResults('f6')
# Out:
# ----------------------------------------------------------
# Basic GP result analysis:
#
# Mean R2 score on train data: 0.9279120200166845
# Mean R2 score on test data: 0.883389578717141
# Max R2 score on test data is 0.9706700700906756 for individual (x0 / cos(cos((x0 + -0.52))))
# ----------------------------------------------------------
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_8810/4015370476.py in <module>
# ----> 1 analyseResults('f6')
#
# /tmp/ipykernel_8810/3271892399.py in analyseResults(functionName)
#      20
#      21     sscGPresultsPath = '../results/GP/SSC/' + functionName + '.csv'
# ---> 22     dfSSCGP = pd.read_csv (sscGPresultsPath)
#      23
#      24     print("GP with Semantic Similarity-based Crossover result analysis:")
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../results/GP/SSC/f6.csv'

# %%
analyseResults('f7')
# Out:
# ----------------------------------------------------------
# Basic GP result analysis:
#
# Mean R2 score on train data: 0.9596784225383559
# Mean R2 score on test data: 0.9500241358356488
# Max R2 score on test data is 0.9973906465943764 for individual (x0 + ((x0 * 0.359)**((x0 / x0)))), simplified to 1.359*x0
# ----------------------------------------------------------
#
# GP with Semantic Similarity-based Crossover result analysis:
#
# Mean R2 score on train data: 0.9679834285069145
# Mean R2 score on test data: 0.9587007101746469
# Max R2 score on test data is 0.9981749066602812 for individual (x0 / sin(0.81)), simplified to 1.38066782815756*x0
# ----------------------------------------------------------

# %%
analyseResults('f8')
# Out:
# ----------------------------------------------------------
# Basic GP result analysis:
#
# Mean R2 score on train data: 0.8571601265021551
# Mean R2 score on test data: 0.7159485160505176
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'BestIndividualSimplified'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_8810/1668116081.py in <module>
# ----> 1 analyseResults('f8')
#
# /tmp/ipykernel_8810/2569189731.py in analyseResults(functionName)
#      15     bestResultRowBasicGP = dfBasicGP.iloc[[maxTestScoreRowIdxBasicGP]]
#      16     #print(bestResultRowBasicGP)
# ---> 17     print('Max R2 score on test data is {0} for individual {1}, simplified to {2}'.format(bestResultRowBasicGP.iloc[0]['TestR2Score'], bestResultRowBasicGP.iloc[0]['BestIndividual'], bestResultRowBasicGP.iloc[0]['BestIndividualSimplified']))
#      18     print('----------------------------------------------------------')
#      19     print()
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'BestIndividualSimplified'

# %%
analyseResults('f9')
# Out:
# ----------------------------------------------------------
# Basic GP result analysis:
#
# Mean R2 score on train data: 0.9497057072084765
# Mean R2 score on test data: 0.9547554275419929
# Max R2 score on test data is 1.0 for individual (cos(x1) * (sin(x0) + sin(x0))), simplified to 2*sin(x0)*cos(x1)
# ----------------------------------------------------------
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_8810/359486431.py in <module>
# ----> 1 analyseResults('f9')
#
# /tmp/ipykernel_8810/2569189731.py in analyseResults(functionName)
#      20
#      21     sscGPresultsPath = '../results/GP/SSC/' + functionName + '.csv'
# ---> 22     dfSSCGP = pd.read_csv (sscGPresultsPath)
#      23
#      24     print("GP with Semantic Similarity-based Crossover result analysis:")
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../results/GP/SSC/f9.csv'

# %%
analyseResults('yacht_hydrodynamics')
# Out:
# ----------------------------------------------------------
# Basic GP result analysis:
#
# Mean R2 score on train data: 0.34571964537811645
# Mean R2 score on test data: 0.40237680345472276
# Max R2 score on test data is 0.8004315745683241 for individual ((x1 * x3) * (((x2**(x2)) * (x3**(((x2 * cos(cos((x5 + (x2 / x4))))) * log(x5))))) - (x5**(x4))))
# ----------------------------------------------------------
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_8810/3329720742.py in <module>
# ----> 1 analyseResults('yacht_hydrodynamics')
#
# /tmp/ipykernel_8810/3271892399.py in analyseResults(functionName)
#      20
#      21     sscGPresultsPath = '../results/GP/SSC/' + functionName + '.csv'
# ---> 22     dfSSCGP = pd.read_csv (sscGPresultsPath)
#      23
#      24     print("GP with Semantic Similarity-based Crossover result analysis:")
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~/.virtualenvs/cv/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../results/GP/SSC/yacht_hydrodynamics.csv'
